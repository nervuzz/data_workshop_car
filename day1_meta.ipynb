# %%
cd "drive/My Drive/Colab Notebooks/data_workshop_car/"
# Out:
# /content/drive/My Drive/Colab Notebooks/data_workshop_car

# %%
# !curl -L http://bit.ly/dw_car_data -o data/car.h5

# %%
# !pip install --upgrade tables
import pandas as pd

# %%
df = pd.read_hdf('data/car.h5')
df.shape
# Out:
# (106494, 155)

# %%
df.sample(2)
# Out:
#                                               breadcrumb  ... car_id
# 98322         [Osobowe, Audi, Q7, Audi Q7 I (2005-2015)]  ...  98322
# 63141  [Osobowe, Volkswagen, Passat, Volkswagen Passa...  ...  63141
#
# [2 rows x 155 columns]
